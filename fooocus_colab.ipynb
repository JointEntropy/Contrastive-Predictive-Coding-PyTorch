# %% [markdown]
# <a href="https://colab.research.google.com/github/JointEntropy/Contrastive-Predictive-Coding-PyTorch/blob/master/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# 1

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# The folder you are executing pip from can no longer be found.
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Counting objects: 100% (1361/1361), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 6725 (delta 1302), reused 1210 (delta 1210), pack-reused 5364 (from 1)
# Receiving objects: 100% (6725/6725), 33.19 MiB | 24.61 MiB/s, done.
# Resolving deltas: 100% (3929/3929), done.
# /content/Fooocus

# %%
## INPUT !ls /content/Fooocus/models/loras/put_loras_here
# !cp /content/drive/MyDrive/pixel-art-xl-v1.1.safetensors  /content/Fooocus/models/loras/
# OUTPUT
# !ls /content/Fooocus/models/loras/
# Out:
# pixel-art-xl-v1.1.safetensors  put_loras_here

# %%
#
# !ls /content/drive/MyDrive/pixel-art-xl-v1.1.safetensors

# %%
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 21.7MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 17.5MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 152MB/s]
# ...
